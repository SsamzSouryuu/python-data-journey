# %% [markdown]
# <a href="https://colab.research.google.com/github/SsamzSouryuu/python-data-journey/blob/main/Modul1_Var_%26_Data_Type_Tristan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Kadar_Air = 8.9
print(type(Kadar_Air))
# Out:
# <class 'float'>

# %%
Berat_Basah = 100
Berat_Kering = 85
Kadar_Air = ((Berat_Basah - Berat_Kering) / Berat_Basah) * 100
print(f"Kadar air: {Kadar_Air}%")
# Out:
# Kadar air: 15.0%

# %%
Kadar_Air = 15.0
print(Kadar_Air > 10)
# Out:
# True

# %%
Berat_Basah = input("Masukkan berat basah (gram): ")
print(type(Berat_Basah))
# Out:
# Masukkan berat basah (gram): 2
# <class 'str'>

# %%
BeratBasah = int(input("Masukkan berat basah (gram):"))
BeratKering = int(input("Masukkan berat kering (gram):"))
KadarAir = ((BeratBasah - BeratKering)/ BeratBasah) * 100
print(f"Kadar air sampel ini adalah: {KadarAir}%")
# Out:
# Masukkan berat basah (gram):10
# Masukkan berat kering (gram):2
# Kadar air sampel ini adalah: 80.0%

# %%
BeratBasah = float(input("Masukkan berat basah (gram):"))
BeratKering = float(input("Masukkan berat kering (gram):"))
KadarAir = ((BeratBasah - BeratKering)/ BeratBasah) * 100
print(f"Kadar air sampel ini adalah: {KadarAir}%")
# Out:
# Masukkan berat basah (gram):100
# Masukkan berat kering (gram):45.3
# Kadar air sampel ini adalah: 54.7%

# %%
Kadar_Air = 13.3
pH = 3.4
Lolos_QC = (Kadar_Air < 14.0) and (pH > 3.5)
print (Lolos_QC)
# Out:
# False

# %%
BeratBasah = float(input("Masukkan berat basah (gram):"))
BeratKering = float(input("Masukkan berat kering (gram):"))
KadarAir = ((BeratBasah - BeratKering)/ BeratBasah) * 100
print(f"Kadar air sampel ini adalah: {KadarAir}%")
Lolos_QC = KadarAir < 14.0
print(Lolos_QC)
# Out:
# Masukkan berat basah (gram):100
# Masukkan berat kering (gram):64.6
# Kadar air sampel ini adalah: 35.400000000000006%
# False

# %%
BeratBasah = float(input("Masukkan berat basah (gram):"))
BeratKering = float(input("Masukkan berat kering (gram):"))
KadarAir = ((BeratBasah - BeratKering)/ BeratBasah) * 100
print(f"Kadar air sampel ini adalah: {KadarAir: .2f}%")
Lolos_QC = KadarAir < 14.0
print(Lolos_QC)
# Out:
# Masukkan berat basah (gram):100
# Masukkan berat kering (gram):64.6
# Kadar air sampel ini adalah:  35.40%
# False
