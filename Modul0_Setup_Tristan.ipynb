# %% [markdown]
# <a href="https://colab.research.google.com/github/SsamzSouryuu/python-data-journey/blob/main/Modul0_Setup_Tristan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Halo, Ini lab data pertamanku.")
# Out:
# Halo, Ini lab data pertamanku.

# %%
print ("Produk yang di uji: Keripik Pisang")
print ("Kode Batch: BTC-001")
print ("Tanggal Uji: 18 Juli 2026")
# Out:
# Produk yang di uji: Keripik Pisang
# Kode Batch: BTC-001
# Tanggal Uji: 18 Juli 2026

# %%
Produk = "Keripik Pisang"
Kode_Batch = "BTC-001"
Tanggal_Uji = "18 Juli 2026"
print (Produk, Kode_Batch, Tanggal_Uji, sep=",")
# Out:
# Keripik Pisang,BTC-001,18 Juli 2026

# %%
Produk = "Keripik Pisang"
Kode_Batch = "BTC-001"
Tanggal_Uji = "18 Juli 2026"
print (f"{Produk}\n{Kode_Batch}\n{Tanggal_Uji}")
# Out:
# Keripik Pisang
# BTC-001
# 18 Juli 2026

# %%
Produk = "Keripik Pisang"
print("Nama produknya: {Produk}")
# Out:
# Nama produknya: {Produk}

# %%
print(f"Nama produknya: {Produk}")
# Out:
# Nama produknya: Keripik Pisang

# %%
print (f"Nama Produk: {Produk} \n Kode Batch: {Kode_Batch}")
# Out:
# Nama Produk: Keripik Pisang
#  Kode Batch: BTC-001
